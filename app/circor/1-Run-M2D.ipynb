# %% [markdown]
# # Example training/test a model with pre-trained M2D
#
# The following will run an experiment using M2D on the 2nd stratified split of the CirCor dataset using a detailed command line instead of the batch scripts we actually used.
#
# - The command line is:
#     ```sh
#     python circor_eval.py config/m2d.yaml circor2 weight_file=../m2d_vit_base-80x608p16x16-220930-mr7_enconly/checkpoint-300.pth,encoder_only=True,freeze_embed=True --lr=0.00025 --freq_mask 0 --time_mask 0 --training_mask 0.2 --mixup 0.0 --rrc False --epochs 50 --warmup_epochs 5 --seed 7 --batch_size 32
#     ```
# - You need to download the pre-trained M2D weight if you do not have it:
#     ```sh
#     wget https://github.com/nttcslab/m2d/releases/download/v0.1.0/m2d_vit_base-80x608p16x16-220930-mr7_enconly.zip
#     unzip m2d_vit_base-80x608p16x16-220930-mr7_enconly.zip
#     ```

# %% [markdown]
# ## Run fine-tuning in the folder `evar`

# %%
# %cd evar
# Out:
# /lab/M2D2022prep/app/circor/evar

# %%
! CUDA_VISIBLE_DEVICES=2 python circor_eval.py config/m2d.yaml circor2 weight_file=../m2d_vit_base-80x608p16x16-220930-mr7_enconly/checkpoint-300.pth,encoder_only=True,freeze_embed=True --lr=0.00025 --freq_mask 0 --time_mask 0 --training_mask 0.2 --mixup 0.0 --rrc False --epochs 50 --warmup_epochs 5 --seed 7 --batch_size 32
# Out:
# weight_file=../m2d_vit_base-80x608p16x16-220930-mr7_enconly/checkpoint-300.pth,encoder_only=True,freeze_embed=True
# +task_metadata=evar/metadata/circor2.csv,+task_data=work/16k/circor2,+unit_samples=80000
#
# Logging to logs/m2d_vit_base-80x608p16x16-220930-mr7_enconly-checkpoint-300_circor2_634f5cd9/log.txt
# ...

# %% [markdown]
# ## Check the results
#
# This resulted in weighted_accuracy: 0.84000 and UAR: 0.72563.
#
# The results are stored in results/circor-scores.csv.

# %%
import pandas as pd

pd.read_csv('results/circor-scores.csv')
# Out:
#   representation     task  wacc       uar  r_Present  r_Unknown  r_Absent  \
# 0        circor2  circor2  0.84  0.725633   0.977778   0.411765  0.787356
#
#                                          weight_file  \
# 0  ../m2d_vit_base-80x608p16x16-220930-mr7_enconl...
#
#                                               run_id  \
# 0  m2d_vit_base-80x608p16x16-220930-mr7_enconly-c...
#
#                                               report
# 0  Finetuning m2d_vit_base-80x608p16x16-220930-mr...
